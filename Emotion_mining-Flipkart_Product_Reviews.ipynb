# %% [markdown]
# # Emotion Mining / Sentimental Analysis of Flipkart Product Reviews

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Web Scraping a Washing Machine Reviews data from Flipkart's website
cust_names=[]
cust_reviews=[]

page_num= input("Enter number of pages") #here enter number of pages as 70
for i in range(1,int(page_num)+1):
   link="https://www.flipkart.com/ifb-6-kg-5-star-2x-power-steam-hard-water-wash-fully-automatic-front-load-in-built-heater-white/product-reviews/itm3bf21ef8dc5e7?pid=WMNGDMYHAKGZHEPK&lid=LSTWMNGDMYHAKGZHEPKZXNDIY&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT&page="+str(i)
   req=requests.get(link)
   content=BeautifulSoup(req.content,'html.parser')
   #reviews=content.find_all("div",class_="row")
   #reviews=content.find_all('span',class_="_1H-bmy")
   names=content.find_all('p',class_="_2sc7ZR _2V5EHH")
   reviews=content.find_all(class_="t-ZTKy")
   
   for i in names:
      cust_names.append(i.text)
   for i in reviews:
      cust_reviews.append(i.text)

# %%
#Printing customer names
for i in cust_names:
    print(i)
# Out:
# Tapas Datta
# Flipkart Customer
# Sayantan Chakraborty
# Sunny  lalwani
# Pushkar Kumar Tyagi
# Flipkart Customer
# MALLIDI SRINIVASA  REDDY
# Vaddadhi Karthik
# RISHAD MOOTHEDATH
# Kula Sekhar
# Prathap G S
# KARRAVULA AJAY KUMAR
# Ganja  Sarfaraj
# Manish Gupta
# Flipkart Customer
# Flipkart Customer
# Aishwarya  Durgabhavani
# Flipkart Customer
# Sushil Kumar
# Abhishek Tomar
# Ashwin Kumar
# Customer
# Siva
# Flipkart Customer
# Tarunbhai manubhai Baldaniya
# Md Ejaz  Ahmed
# Flipkart Customer
# Satish  Bansode
# Mohan Burle
# Rony Bhai
# ANANTHANARAYANAN  P R
# Gourav Kumar
# Flipkart Customer
# Amit Kumar
# SURESH KUDAKA
# Hemadri Atthuru
# Sangram Chandgude
# Venkateshwaralu Gopi
# NAVEEN REDDY VEERABHADRA
# Flipkart Customer
# Vinod  kumar Gupta
# Prabhu Veer Kallem
# Santhosh
# vijay prakash
# Sreejith Sudarshanan
# Flipkart Customer
# Vinayak Tallalli
# Veeraraghavan S
# Flipkart Customer
# shubham  kumar
# Jishnu Ramesan
# parimal nandaniya
# Flipkart Customer
# Bharathi CB
# DHIRENDRA  KUMAR
# Bhuvan  Kumar
# pendam harishankar
# Flipkart Customer
# Onkar Deshpande
# Saicharan  Kothapalli
# Susanta kumar Sahu
# Ullasa
# Mahendra J
# sarath  kumar
# Santhosh Thatikonda
# Pratipada Jena
# Flipkart Customer
# Jaya Babu
# Flipkart Customer
# Flipkart Customer
# Anuj  Chauhan
# Arun Kumar M
# RamaChandraRao Tentu
# Manju
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer
# Flipkart Customer
# Washing machine is nice     But the people came for Give demo has take so much money for washing machine stand and cover etc.........please take care of itREAD MORE
# Flipkart people reducing the exchange value for no reason,In my case they diminished of Rs 1450 in exchange value for quoting missing of bottom cap which never exist in my previous model.READ MORE
# Good product ...but takes more timeREAD MORE
# It's was the great product and price value. I am using daily and getting the good quality of washing and spinning.so, i recommend to all you can buy it.READ MORE
# niceREAD MORE
# Thank you so much filpcardREAD MORE
# Nice product in good price,value for your money,works well for me.READ MORE
# Super duper hit product with best rateREAD MORE
# nice product with low costREAD MORE

# %%
#Storing customer data in excel workbook manually and retriving data from that excelsheet
rev=pd.read_excel("C:\\Users\\MOHD SHOEB\\OneDrive\\Desktop\\Excelr Assignments\\Text Mining\\reviews.xlsx")
rev=rev.drop(rev.iloc[:,2:],axis=1)
rev
# Out:
#                cust_names                                       cust_reviews
# 0             Tapas Datta                   Quality is good enough.READ MORE
# 1       Flipkart Customer                                      NiceREAD MORE
# 2    Sayantan Chakraborty  Fully satisfied with this brand new item ??REA...
# 3          Sunny  lalwani  Should not buy this IFB technology any product...
# 4     Pushkar Kumar Tyagi                                      GoodREAD MORE
# ..                    ...                                                ...
# 625            Atul  Gore                                      niceREAD MORE
# 626       Umesh Chandgude                Thank you so much filpcardREAD MORE
# 627          akash tarale  Nice product in good price,value for your mone...
# 628        Sandeep Sabale    Super duper hit product with best rateREAD MORE
# 629          Yogesh Patil                nice product with low costREAD MORE
#
# [630 rows x 2 columns]

# %%
#dropping NA values 
rev=rev.dropna()
rev
# Out:
#                cust_names                                       cust_reviews
# 0             Tapas Datta                   Quality is good enough.READ MORE
# 1       Flipkart Customer                                      NiceREAD MORE
# 2    Sayantan Chakraborty  Fully satisfied with this brand new item ??REA...
# 3          Sunny  lalwani  Should not buy this IFB technology any product...
# 4     Pushkar Kumar Tyagi                                      GoodREAD MORE
# ..                    ...                                                ...
# 625            Atul  Gore                                      niceREAD MORE
# 626       Umesh Chandgude                Thank you so much filpcardREAD MORE
# 627          akash tarale  Nice product in good price,value for your mone...
# 628        Sandeep Sabale    Super duper hit product with best rateREAD MORE
# 629          Yogesh Patil                nice product with low costREAD MORE
#
# [629 rows x 2 columns]

# %%
#dropping cust names to preserve the privacy of the people
rev=rev.drop(rev.iloc[:,:1],axis=1)
rev
# Out:
#                                           cust_reviews
# 0                     Quality is good enough.READ MORE
# 1                                        NiceREAD MORE
# 2    Fully satisfied with this brand new item ??REA...
# 3    Should not buy this IFB technology any product...
# 4                                        GoodREAD MORE
# ..                                                 ...
# 625                                      niceREAD MORE
# 626                Thank you so much filpcardREAD MORE
# 627  Nice product in good price,value for your mone...
# 628    Super duper hit product with best rateREAD MORE
# 629                nice product with low costREAD MORE
#
# [629 rows x 1 columns]

# %% [markdown]
# # Data Cleaning

# %%
import re #regular expression
import string

def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', ' ', text)
    text = re.sub("[0-9" "]+"," ",text)
    text = re.sub('[‘’“”…]', ' ', text)
    text = re.sub('read more',' ',text)
    return text

clean = lambda x: clean_text(x)

# %%
rev['cust_reviews'] = rev.cust_reviews.apply(clean)
rev
# Out:
#                                           cust_reviews
# 0                              quality is good enough
# 1                                                nice
# 2           fully satisfied with this brand new item
# 3    should not buy this ifb technology any product...
# 4                                                good
# ..                                                 ...
# 625                                              nice
# 626                        thank you so much filpcard
# 627  nice product in good pricevalue for your money...
# 628            super duper hit product with best rate
# 629                        nice product with low cost
#
# [629 rows x 1 columns]

# %%
from wordcloud import WordCloud, STOPWORDS
import spacy
import matplotlib.pyplot as plt

# %%
#Creating Word Cloud which will show the Words frequently used will be in big Sixe and words with less frequency are small in size 
comment_words = ''
stopwords = set(STOPWORDS)
# iterate through the csv file
for val in rev.cust_reviews  :
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
#Parts Of Speech Tagging
nlp= spacy.load('en_core_web_sm')
one_block=rev.cust_reviews[70]
one_block
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style='ent', jupyter=True)
# Out:
# C:\Users\MOHD SHOEB\anaconda3\lib\site-packages\spacy\displacy\__init__.py:215: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">good machine purchased with free mind because   year full machine waranty </div></span>

# %%
for token in doc_block:
    print(token,token.pos_)
# Out:
# good ADJ
# machine NOUN
# purchased VERB
# with ADP
# free ADJ
# mind NOUN
# because SCONJ
#    SPACE
# year NOUN
# full ADJ
# machine NOUN
# waranty NOUN

# %%
#Filtering for nouns and verbs only
noun_verbs=[token.text for token in doc_block if token.pos_ in ('NOUN' , 'VERB')]
print(noun_verbs)
# Out:
# ['machine', 'purchased', 'mind', 'year', 'machine', 'waranty']

# %%
#Counting tokens again
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()

X= cv.fit_transform(noun_verbs)
sum_words= X.sum(axis=0)
word_freq=[(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
word_freq= sorted(word_freq, key=lambda x: x[1], reverse= True)
wf_df=pd.DataFrame(word_freq)
wf_df.columns= ['word','count']
wf_df
# Out:
#         word  count
# 0    machine      2
# 1  purchased      1
# 2       mind      1
# 3       year      1
# 4    waranty      1

# %%
##Visualizing results
#Barchart for  nouns + verbs of a sentence
wf_df[0:10].plot.bar(x='word', figsize=(12,8), title='Top verbs and nouns')
# Out:
# <AxesSubplot:title={'center':'Top verbs and nouns'}, xlabel='word'>

# %% [markdown]
# # Sentimental Analysis

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\MOHD
# [nltk_data]     SHOEB\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#importing affin csv in which there are scores for words giving by well known psychiatrists
afinn=pd.read_csv('C:\\Users\\MOHD SHOEB\\OneDrive\\Desktop\\Excelr Assignments\\Text Mining\\Afinn.csv',sep=',', encoding='latin-1')
afinn.shape
# Out:
# (2477, 2)

# %%
rev=[cust_reviews.strip() for cust_reviews in rev.cust_reviews]  # remove both the leading and the trailing characters
rev=[cust_reviews for cust_reviews in rev if cust_reviews] # removes empty strings, because they are considered in Python as False
rev
# Out:
# ['quality is good enough',
#  'nice',
#  'fully satisfied with this brand new item',
#  'should not buy this ifb technology any product because after some time this company electronic product spread electric current around it ie give electric shock',
#  'good',
#  'simple',
#  'value  for money',
#  'awesome thanks flipkart',
#  'good',
#  'after using   is not working so many times errors worst dont buy this item every one',
#  'nice',
#  'excellent',
#  'wash clothes are perfect cleanvoice and vibration is too low',
#  'in this budget nice product',
#  'its good',
#  'best at this price range using since   yrs no issues till now consa bit noisytakes     mins to   hrs for a cycle in cotton wash method',
#  'nice product good workingclothes r very clean',
#  'product is comparatively good than other company its heavy which gives benifits during spin and washing its good    good for small family   is sufficient',
#  'good product got for   in big billion day steam wash all good and value for money',
#  'excellent',
#  'good',
#  'no timer display this is old model not worth for money',
#  'good product',
#  'valuable for money very exhalent im happy buying this washing machine',
#  'good product',
#  'very good product',
#  'the worst service ever first of all if u r taking for ur moms who dont know english then its a big no for them it doesnt show time we need to set time according to written format on the spin as it dont show time gow much it takes to wash obviously we have to wait till completes it takes long to washit worked well for couple of weeks then the trouble started it dont wash clothes neither takes water we called customer care they came n said our home have some power fluctuations i',
#  'value for money',
#  'wonderful product',
#  'best price product',
#  'very good',
#  'good product only absent digital panel for shown washing time',
#  'worst experience with ifb washing machine   front load if washing done spin not working express wash take more than one hour even run   washing mode not completed  i wasted   this useless ifb i thought it was branded and working in condition but overall my experience disgusting and wasted my money',
#  'washing time has neither mentioned on flipkart nor the installation person said us its taking   hr or more in quick wash no option for hot waterand you cant upgrade it after purchasing',
#  'very good product and noice less operation value for money',
#  'good',
#  'value for money but facing some delays for installation',
#  'good',
#  'awesome',
#  'very worst no body installation very very worst after washing cloths dirty not removed very worst machine',
#  'good',
#  'using since two weeks wash quality is good makes very low noise it has both warm and hot water wash wash cycles are little bit longer though but performs well provision only for liquid detergent actually wanted to buy a   kgs machine but wrongly booked a   kg version but satisfied with the performance a family of   can definitely choose this wonderful ifb washing machine',
#  'perfectvalue for money',
#  'good price',
#  'good iteamgood performance',
#  'machine is superb with the lucrative price i bought it for   witg credit card wash quality is good only problem is wash time it take     for mix clothes ifb should consider to reduce washing time i would give   star if the reduce wash time to   minutes',
#  'product was good and working performance is super',
#  'product and the installation was on time',
#  'it is a great product i have been using ifb for last   years i bought it again for my paternal house its the brand you can trust blindly for washing machines',
#  'nice cleaning save water and detergent overall very happy',
#  'nice product',
#  'good',
#  'super',
#  'happy',
#  'good',
#  'good but there is no time display if it is included it is unbeatable product',
#  'super',
#  'nice waching machine',
#  'good',
#  'nice',
#  'good',
#  'good productlooking awesomeworth for money',
#  'no display of timings if you want washing machine with display dont buy this',
#  'good need more colours and customer support',
#  'super',
#  'outstanding performance and installation guys were so friendly and awesome',
#  'flawless performance and awesome onsite service by ifb life made easy just a bit small less clothes get washed',
#  'not bad',
#  'awesome',
#  'we did not like the quality of this residence it also takes a lot of time',
#  'good machine purchased with free mind because   year full machine waranty',
#  'happy with this fully satisfied it',
#  'good product',
#  'good',
#  'super wash',
#  'super',
#  'no match with our earlier   year old elena model front loading   ifb',
#  'ater   days of use started showing problems with belt n spining washing',
#  'very good',
#  'very good',
#  'great product',
#  'good',
#  'its not wrightstand is very poor',
#  'waste product please dont buy this it is not working even after multiple checks and complaints there is no use could not wash even   to   pairs once',
#  'nice product',
#  'compact and superb value for money thanks ifb team',
#  'products is good value for money',
#  'product is good but it takes more than   hour to clean clothes and some times it works only on spin and ringe option and give indication of irror wash programs timming should be improved by ifb brand washing machine',
#  'it is a very good machine its performance is very good but its takes long time',
#  'best purchace',
#  'good product',
#  'it seems awesome at first hand experience lets see how it goes in future',
#  'excellent',
#  'best in the category please ifb include stand price',
#  'happy with this product good performance value for money but they didnt taken my old mechanic this is only complaints',
#  'very very bad product',
#  'good',
#  'supar',
#  'ifb washing meshion is the best product',
#  'nice product',
#  'excellent',
#  'good working',
#  'quality product',
#  'machine quality is superb and excellent working',
#  'this is amazing product',
#  'very good',
#  'easy operation and best washing',
#  'good',
#  'the machine is perfect value for money it has good wash   years of warrantysteam wash facilityit is stable during washing and spinningnot making that much of noisedirect drive is much betterbut more expensive',
#  'simply ifb is best in washing machines and super helpful costomer service from ifb',
#  'not worth of money',
#  'very good product',
#  'door lock system worst',
#  'ifb washing machine always best',
#  'good for small family   to   personquite and works good',
#  'exlent',
#  'not responsible prices',
#  'fabulus  productgood enginer mrshankar installed and explain everything to usvalue for money',
#  'value for money',
#  'good product',
#  'product is nice but instalation guy was not good',
#  'worst performance doesnt clean even the easily removable stains white clothes get more dirty after washing in this all it does is just rinsing the clothes in water it doesnt clean clothes at all',
#  'value for money',
#  'very good product excellent performance value for money',
#  'good product value of money',
#  'worst experience with installation team no proper demo has been provided always they want to sell the products they have very much disappointed with the way they behave during visit for installation of my ifb   washing machine',
#  'amazing',
#  'ok',
#  'super',
#  'installation explained very well',
#  'good',
#  'nice product and its washingqualityis superbvalue for money',
#  'nice',
#  'im really satisfied with my purchase product',
#  'great product its working as fantasticlove you ifb',
#  'product is really good but team come for installation doesnt tell properly how to operate',
#  'low sound and vibration over all good product',
#  'performance and price is good but stand and filter more cost compare to online',
#  'good product',
#  'wonderful  to have such a wonderful  product',
#  'very good and careful and please all customer  choose this company this is the best brand',
#  'good',
#  'value for money',
#  'very nice',
#  'good',
#  'digital timer is much better for this product required',
#  'excellent performance',
#  'best budget washing machine',
#  'value for money',
#  'program is designed not good it will be taken    worst product west of money',
#  'not worthyno qualitytaking so much time to wash',
#  'very good product',
#  'good product with value of money',
#  'good quality productvery good services and customer support from ifb',
#  'horrible installation service by ifb once you buy their product they dont care about your installation its almost    days of delivery but still its pending for installation buy at our own risk',
#  'nice product',
#  'excellent',
#  'its good but performance is ok',
#  'awesome',
#  'good product from ifb fully satisfied with the washing machine',
#  'good',
#  'chep and best',
#  'best washing machine in this segment good quality and efficient work value for money thankyou flipkart and samsung',
#  'noise over and other brand was over time delay pls do not buy this',
#  'value for money',
#  'good',
#  'worst product i ever bought  disappointed',
#  'ok',
#  'nice newly added express wash option washed within   min rapid wash option takes one hour',
#  'very asthetical',
#  'nice',
#  'noting can be better than this at his price',
#  'nice product',
#  'excellent product',
#  'nice product from flipkart installation little bit late',
#  'i am very happy purchase this product',
#  'for normal wash it takes minimum   minutes and it takes more electricity  and also it makes sound and also it shake while washing',
#  'very good product',
#  'good',
#  'after   machine not working better go for other product control panel not working properly drum aslo have issues service not good',
#  'worst experience on the product',
#  'bad product',
#  'good oknot best',
#  'very good my family',
#  'exlent super',
#  'not so good product no timers not a fully automatic one it wont accept detergent and additives at program setup process ifb detergent complimentary kit is not provided delayed installation but cooperative',
#  'very bad',
#  'done good',
#  'worth of moneysuprb working',
#  'used for   week washing and cleaning of clothes is satisfactory dont ever go for smart inverter machines as pcb has to be changed frequently which is quite costly',
#  'nice product',
#  'very good product and very low noice we loved it the installation boy was very humble and give good explanation i love ifb products its very quality measures thank you',
#  'good',
#  'nice',
#  'error problem very bad',
#  'very good product',
#  'not working good not rinsing and draining showing half hour but taking too much time for washing clothesreally unhappy with product',
#  'returns please very low capacity',
#  'value for money best washing machine under   it take maximum   hours minimum   minutes you can use it daily basis because it takes very less light i suggest you to buy it',
#  'totally satisfaction but only use ifb liquid matic detergent definitely u will get best result value for money',
#  'nice',
#  'highly recommended',
#  'i want to return washing meachine its not working properly',
#  'good',
#  'super',
#  'ok',
#  'nice',
#  'very nice product',
#  'installation done  recently and performance looks good inbuilt programs good taken extra water purifier due to ground water supply at my home better to take stabilizer  since the machine had very sensible sensors may be impact from high voltage',
#  'super',
#  'very nice',
#  'worst quality and ifb technician also bad',
#  'superb quality',
#  'nice product but no digital display',
#  'good working',
#  'very nice product',
#  'nice product go for it',
#  'as expected ifb  is a all round performer thanks to the seller and flipkart',
#  'very good',
#  'nice',
#  'i used ifb serena sx model since   well working no complaintsthis dasara filipcart sale amazing offers i replace to ifb   kg divavery good product wash quality very goodvery low noisevalue for money',
#  'good product',
#  'iam reaily expect more loud noise and not wash praporly and no display',
#  'inlet pipe is short',
#  'good one',
#  'best quality value for money best performance',
#  'v good',
#  'very nice',
#  'performance is good but there is no display for showing wash timetimer difficult to identify the remaining wash time also there is   no seperate tray for detergents and fabric conditioners',
#  'im happy',
#  'nice product',
#  'more than sufficient for a couple',
#  'installation and demo were fine ifb washing machine working well so far thanks flipkart for the good offer',
#  'good performance good service for ifb',
#  'overall good product easy to maintain',
#  'really ifb cheatingits does not have steam and can wash only less quantity clothsand its vibration is heavy every time when i wash i need to stand nearby totally washing is good orther that its its not comfortable',
#  'dont buy this accessories will cost a lot machine is now malfunctioning worst experience',
#  'its awesome product worth for money',
#  'such a nice product performing good',
#  'machine performance is good but ifb other accessories is costly',
#  'good product',
#  'very nice i like it value for money',
#  'first of all the look is so classy  it is neatly designed by ifb  packed with features and performing well  thanks to flipkart for delivered in time and installation',
#  'nice washing and looks too but if you are   members then go for it otherwise go for   variant',
#  'very good product low price very useful budget plan',
#  'machine was goodthe delivery boys are very nice they fit the machine in   floor but they dont ask for any tips nice',
#  'the best',
#  'no word to describe how bad is it',
#  'she is so beautifulamazing producti m loving it',
#  'very good product at this price',
#  'good product and services',
#  'was delivered on time and i perfect condition carefully transported  thanks to flipkart  technician appointment also done on time  within one day of delivery  all setup done and started using the wm  all nice',
#  'nice product',
#  'not working in   use',
#  'very nice product',
#  'great product im very happy',
#  'super quality',
#  'thank you flipkart',
#  'nice product',
#  'very good washing machine specially very good wash jeans pant',
#  'superb product i loved itwashing quality also good',
#  'its price worthy and excellent machine',
#  'this ok for   to   people   you cant wash your blanket  in this',
#  'good service and nice working',
#  'good',
#  'very good washing machine working fine',
#  'satisfied thank you',
#  'dnt waste your money',
#  'too much noise during washing not silent as other machines',
#  'its good',
#  'excellent',
#  'good',
#  'it was very good experience with flipkart as i got on time delivery and installation on time specially installation and delivery team are not doing marketing related to product and also my query related to bill and other things have been solved everytime which is very good part of them i would highly recommend flip kart',
#  'good washmeshine',
#  'very bad machine',
#  'very nice washing',
#  'very nice product',
#  'good product',
#  'thank you flipkart',
#  'more sound',
#  'awesome',
#  'very good product',
#  'would have been nice if it could show the time it takes for each washmiw we just have to assume  and wait',
#  'poor performance',
#  'quality washing machinemedium noiseeasy to operate',
#  'good',
#  'well and excellent',
#  'worth to buy',
#  'nice job',
#  'feel the difference between hand wash and the machine felt the clothes like a feather with the liquid detergent awesome',
#  'nice',
#  'nice',
#  'goood',
#  'very nice product thanks flipkart',
#  'very good product',
#  'super',
#  'it is good washing machine  ifb is always favorite brand for me',
#  'i like this',
#  'within week getting multiple type errorwhere click on return in flipkart app it gives error',
#  'satisfactory',
#  'superb',
#  'instaletion very badbut mituin is very good product thankyou ifb',
#  'value of money',
#  'good',
#  'takes tooo much of time to complete the washing nearly   minutes',
#  'machine performance is very good i satisfied with it only problem is installation because guy came for installation is foolish',
#  'very good product value for money',
#  'great machine for small homes simple menu with no complications performance is great build quality is also amazing',
#  'installation and demo was gud politely done by person',
#  'i hope good product have to see',
#  'good one',
#  'washing machine working condition super washing  ifb good manufacturing',
#  'machine performance is too bad every   technician requires for settingstoo bad performancetotally disappointed',
#  'very good',
#  'washing machine super',
#  'good product',
#  'working great',
#  'excellent product i love this',
#  'old modelwater level not adjustable and not cleaning properly as expected',
#  'washing machine working fine but who come for the installation they are forcefully asking for no warranty agreement because i rejected to buy filter this guys are charging more money on extra pipes and not agree with outside products which is power cost then ifb products',
#  'not at all good product recommend not to buy this hell product no service for installation guy came and not installed properly and not even pic the call he took the link and rate given by himself    no service frustrated water not going outside drain and spin not happening brand new product having many issue',
#  'good machine very fair pricegood working',
#  'good product as per schedule delivered and quick installation keep it flipkart',
#  'nice product',
#  'working good',
#  'great discounts superb serviceifb washing machines works fineperformance good',
#  'ok',
#  'this is my   purchase of front load ifb machine excellent performance and good support from ifb',
#  'product wise ok no timer display but the installation guy was so rude and forcing to sell his other products',
#  'horrible  dangerous vibrations when spin mode',
#  'superb quality',
#  'its taking too much time performance not good',
#  'looks good works fine',
#  'it s very nice',
#  'nice so happy',
#  'nice product',
#  'not performed as per requirementsvery slowly working dry not work properly',
#  'good product',
#  'i expected same product and i will receive perfect machine without damage thank flipkart',
#  'its worst performance cloths are not cleaning properly time taking process quick wash   min and mixed fabrics   hr   min worst',
#  'good',
#  'washing quality is good',
#  'very good experience on the product and looking awesomethere is no sound of end door',
#  'love ifb product awesome performance',
#  'fully satisfied in delivery installation demo and its washing perfimance',
#  'installation is too late but product is nice',
#  'very good',
#  'already a ifb customer so no need to tell something ifb is always good',
#  'super',
#  'working good now will add review after   months',
#  'prize is good',
#  'good',
#  'super product',
#  'nice washing machine value for moneyi gift this to my mom love it superrr',
#  'super qality',
#  'taking atleast one hour for washing',
#  'good product',
#  'good super',
#  'excellent quality',
#  'exelent',
#  'good qualityawasome product good wash quality',
#  'instalation time delay by the service team else all are good',
#  'tq',
#  'good',
#  'good mchine',
#  'very good performanace',
#  'clothes are not drying',
#  'delivery is taking more time rather than that all the things are goodinstallation person came within   hrsmachine packing is good and there is no damageifb machine always   in performance',
#  'the outlet pipe that came with machine is so small that it does not go till the drainage line and they charge u extra for the big pipe atleast pipe provided with machine should be big',
#  'good for small family',
#  'last   day   wash good',
#  'good product and fast installation',
#  'best',
#  'very nice',
#  'super ssafae',
#  'just go for it if youre not heavy user',
#  'nice product',
#  'nice product',
#  'nice',
#  'awesome and perfect product',
#  'very good',
#  'excellent product',
#  'delivery and installation in perfect timequality is goodafter sales service   years peace s of mind',
#  'very good',
#  'worst productit takes more than   hours for single garmentand within   days it stopped working',
#  'good',
#  'it is a good machine only it has one tray for detergent so one has to add the softener later also since there is no time display its hard to know the cycle timings',
#  'super',
#  'size is suitable for max   persons the machine does the job without much hassle in the basic mode for day to day clothes',
#  'nice product',
#  'good performance',
#  'nice product',
#  'good',
#  'good',
#  'so far so good',
#  'good product',
#  'very good performance',
#  'totally disappointed  not proper working if you complain there is no problem solve',
#  'good  as expected',
#  'good',
#  'great buy ifb quality unmistakably good',
#  'very good  washing machine and ifb it is my favorite indian company',
#  'no display low quality shell no glass door no compartment for fabric conditioner quality not upto the mark',
#  'lowest price satisfaction',
#  'good and clean wash good perfornance only thing not great is it takes bit longer for any wash',
#  'best product excellent  working',
#  'its good washing machine',
#  'value for money',
#  'very nice',
#  'washing machine and flipkart delivery are excellent',
#  'good product fast delivery',
#  'ifb good',
#  'superb',
#  'good product',
#  'nice',
#  'worst product waste of money don t waste your money on that shittdisgusting product total shitt',
#  'nice',
#  'just received the machine and used it for a single wash the performance is good as expected and the operation is vibration free one feature that is missing is there is no additional space for adding detol or comfortwill update if any issue faced later',
#  'satisfaction of the product',
#  'excellent machine',
#  'really good one previously i used   know i purchased   it s good for performance',
#  'nice product',
#  'considering this price product is wonderful',
#  'nice product',
#  'excellent product',
#  'very good product',
#  'tq ifb',
#  'getting more noise and disturbance shaking washing machine very much and moving to one corner to another corner',
#  'not bad',
#  'thank you',
#  'goo product value for money',
#  'value for money',
#  'good product',
#  'it is very long hours for wash and not money worthy',
#  'nice product',
#  'good machine',
#  'superb machine working smoothly not even a single drop off water after completing the washing cycle so easy to dry initially had dbt abt delivery and working but everything was done nicely',
#  'super quality',
#  'excellent woking as compare to etc other',
#  'good product',
#  'best value',
#  'good product',
#  'the delivery is very good but the service is very badthe performance is good thank you',
#  'i got this product in   very good product',
#  'good one',
#  'value for money',
#  'good',
#  'good product',
#  'liked the product very much and overall experience from ordering to installation to using it for personal purpose all are too good definately i will recommend to have it so peace of mind for atleast   years thanks flipkart and ifb team',
#  'product is okay very poor communication about the product delivery we have received the product after   days from date of booking even this also got by continuous followups with cs team',
#  'thanks to ifb for right choice',
#  'good',
#  'value for money best in entry level front loading washing machines',
#  'spin problem',
#  'awesome quality value for money',
#  'during use my child got electric shock near doorit is not shockproof',
#  'good performance less price only   thank you filpkart',
#  'good',
#  'nice product',
#  'nice product and installation service',
#  'too good',
#  'very nice product',
#  'awesome',
#  'very very bad extange offer it is actually cheating',
#  'fast  delivery good service  providers good product totally  impressed writing  review  after  one week  totally  worth it',
#  'worth for money',
#  'nice',
#  'the inbuilt heater is too good for warm and hot water wash',
#  'good working iam liked',
#  'worst experiencei perchance product   days beforeworst washand only   days its not working today',
#  'washing machine is very good but maintenance charge is so high please reduce the maintenance charge when installing the mession',
#  'worth for money',
#  'superb in budget',
#  'good product and value money',
#  'wow',
#  'everything fine',
#  'superb',
#  'good',
#  'good experience',
#  'very good product',
#  'nowadays ifb is better than any one nice delivery of product and installation was also very good thank for flipkart and ifb for giving best services',
#  'good buy',
#  'good product at reasonable price but it is not taking hot water button option',
#  'good',
#  'everything is good only the display timer is missing',
#  'awesome product from flip kart and ifb good delivery and installation specially the look is cool and awesome thanks flipkart',
#  'infront door its no   i am using this from   yearszero complaint  flipkart delivered on timehighly recommended to buy',
#  'good equipment inlet and outlet pipes very short which leads every customers should buy another inlet and outlet pipes thismay leads to dissatisfaction to customers',
#  'good in this price range',
#  'excellent product',
#  'nice',
#  'worst product pls dont buy this product flipkart brand goods is better than this',
#  'overall performance is good but it doesnt have time limit option to display',
#  'compact sizegood lookingbest performance service should be genuine',
#  'really no any washing machine front of ifbthis is very very very good product',
#  'dont buy this product from flipkart it has not been one month and the drum of machine is not working highly dissappointed and unsatisfied',
#  'its an awesome washing machine tough durablegood brand but it take too much time to clean clothes like for cotton it takes   hour for mixed  clothes     minutes it should be improve and minimize otherwise its good and value for money',
#  'cool',
#  'as compared to my last fully automatic machine of similar load   the new one looks   feels like smaller   takes   hrs to complete a full cotton cycle',
#  'nice one',
#  'more than expected quality and delivery',
#  'nice one',
#  'good product but flipcart service very hopelessalso customer care services is very pathetic  ingenuity',
#  'except delivery and installation which took more than   weeks product is fine the low rating is for the time taken for delivery and because of my numerous calls to the support team for installation',
#  'good',
#  'its worth for money',
#  'machine is ok with preset programs dont have tray for adding fabric softener',
#  'very nice product  thank you flipkart',
#  'good',
#  'superb product',
#  'it has given problem at the time of installation due to high power in our apartment the technician suggested to use ifb stabilizer now it is working well and worth for money good service thank you ifb and flipkart here i am giving   stars',
#  'nice productgreat performancegreat by design on time delivery and perfect installation by technician',
#  'this machine is very nice and good product made in india',
#  'thanks for the good product given by ifb and also free installationservice boys given good service',
#  'nice productdelivery on time  instalation and demo excellent thanks flipkartifb team',
#  'really nice product and working fine',
#  'best washing machine but digital display not required',
#  'one issue is this machine doesnt display completion timeservice of ifb is great but they will try vary hard to sell you their accessories even tell that if you use any stand other than ifb stand they would not be responsible for any damagei agree they could mention it is recommended but they sound like warranty would not be applicable of u use other stand',
#  'nice',
#  'overall product is good drying clothes in mixed fabric is less than expected my earlier top load washing machine is drying clothes better than this even rpm is less than this machine technician said water filter adapter is mandatory for this machine this is disappointed they should include all mandatory items at the time of purchase itself because it cost me extra   rupees after purchase',
#  'excellent',
#  'nice and super',
#  'flipkart quick delivery  installation also thanq u',
#  'good washing machine',
#  'super product',
#  'excellent',
#  'damage product',
#  'nice prodeat',
#  'nice product good service ifb',
#  'nyc',
#  'good',
#  'very good',
#  'excellent machine for small familyeasy to operateno vibration worth it',
#  'vgood',
#  'washing machine  delivered but no installation done in   days just false promises given that this would be done by so and so date but never done highly frustrating there was no plates given to be fixed in bottom for rat protection also something required for the backside',
#  'very bad  ifb not responding for the errors in the machine poor performance from day   more',
#  'iam so happy about this product orginal quality',
#  'good',
#  'very very very bad product',
#  'good one',
#  'good delivery but installation is not good i calling several times but he is not lifting very very experience with installationhe didnt explain properly',
#  'product was too bad and worst service from flipkartit worked fine for just   cyclesdays and then stopped working tired of calling flipkart no response from them',
#  'its basic function machine',
#  'super',
#  'excellent',
#  'nice product',
#  'nice machine as i m using from last couple of months the thing lagging in the machine is it should have screen for timing otherwise best one',
#  'same day water leakage  no timer mirror',
#  'best product at this price compared to other fully automatic   star only because it take around one and half hour per wash and vibrates while spinning even though its installed on solid stone based plateformand company should also inform first time user for required facilities before demonstration and installations',
#  'nice choice washing superit has   washing programsyou can select one as your requirements',
#  'v good',
#  'good quality and performance',
#  'very good product value for the money  satisfied',
#  'good to buy',
#  'good quality and value of money',
#  'flipkart deliver item just in three days in hamirpur himachal pradeshvery good washing machine for small familyi like productthanx flipkart',
#  'super awesome thanks',
#  'good',
#  'received defective product',
#  'good product',
#  'nice machine for small family',
#  'good design',
#  'nice product and overall service',
#  'good',
#  'everything has been said by othersmy review will concentrate on   thingslack of separate space to add fabric conditioners is disappointing and one more thing is ifb accessories like trolley water softener cover and drum washing power which were sold by authorised ifb technician are very costly ifb should consider reducing these prices or it should sold these things on par with market ratei recommend people to buy these accesories from flipkart by looking at ratings trolley by if',
#  'good',
#  'washing quality is very bad after   hours of wash still water comes as a black color raised complaints many times but service is also bad  technician is also not responding well  lose of money dont go for this product',
#  'just waste of money',
#  'nice product',
#  'super sir',
#  'arrived on time and working really well the motor started making more than usual noise but over all its really good',
#  'good enough',
#  'v good',
#  'installation person bad person not good dont purchase in this ifb item in flip kart item is very poor qualitynot purchased this model not support fill kart not shopping in flip kart',
#  'good performance noise little much high little shaking when it spins no time display finished beep sound is too low overall performance is good flipkart delivery is very fast one day delivery next day it installed by ifb technician am happy with purchase thanks to flipkart',
#  'worst experience with customer care tamil language call centerashamed of being tamilian after couple of callsflipkart never gives chance to change slot',
#  'nice',
#  'thanks',
#  'good product',
#  'stand coverfiltershall be made part and parcel of it',
#  'very fast delivery and immediate response and quick installation by ifb',
#  'good',
#  'simply super',
#  'you can by white color which will give you lower price the better washing machine is available sansui   kg steam wash fully automatic that will give you display and other details like time required to wash the cloth once purchased this we can not return now i am regretting for this purchase',
#  'great useful product',
#  'bad product',
#  'best in segment',
#  'seems good but takes  very much time even in quick wash',
#  'looks sleek and compact in size easy to operate very basic functionalities value for money used it twice as of now the installation was good but you require additional pipe to attach to the tap',
#  'installation person behaviour is too horrible he was totaly mad man he was totally irresponsible  unprofessional person  flipkart showing ifb diva aqua sx   wash programme but this machine shows only   wash programme kar do',
#  'best in this price segment blindly go for it',
#  'ifb is world class go for it',
#  'nice',
#  'working properly look is nice',
#  'great experience so far hope it lasts long',
#  'nice machine wash quality good and satisfactory so far after using it for   weeks will update later after using few more days',
#  'very good washing program although it takes more time to do the whole program the demonstration service should be improved',
#  'super excited',
#  'good product',
#  'value for money',
#  'value for moneybest appliance for family of   with normal use',
#  'go for it  i brought it at   and right from delivery to installation everything is so good',
#  'excellent thanks you flipkart',
#  'light is not working',
#  'good',
#  'product is awesome but i want to request flipkart please give facility for change delivery address after  order was placed',
#  'installstion person worst explained and not  fixed stabilizer',
#  'scratched on button panel one rat protection cover is not proper size panel part is out of its place ifbs technician fit it properly',
#  'ifb is a good product',
#  'dont buy thistaking lot of timeno display  we dont know when it will endheavy shakibg while drainno slot for use comfortdettolwarm not working but taking double timeoverall  its a very bad product i called service person multiple times  but they are not responding',
#  'product is value for money but a little noisy and vibration of encloser is irritating and installation is very bad',
#  'good product excellent',
#  'good condition value for money thank you',
#  'good',
#  'pathetic service by flipkart deducted my exchange order value due to no reason they need to hire competent wish master to fulfil customer needsifb is a good machine but i got a very bad value for money',
#  'worth of cost nice products really appreciate it very much',
#  'takes more time to wash',
#  'excellent  product',
#  'product is good working wellfew straches in tranport',
#  'damaged item',
#  'washing machine is nice     but the people came for give demo has take so much money for washing machine stand and cover etcplease take care of it',
#  'flipkart people reducing the exchange value for no reasonin my case they diminished of rs   in exchange value for quoting missing of bottom cap which never exist in my previous model',
#  'good product but takes more time',
#  'its was the great product and price value i am using daily and getting the good quality of washing and spinningso i recommend to all you can buy it',
#  'nice',
#  'thank you so much filpcard',
#  'nice product in good pricevalue for your moneyworks well for me',
#  'super duper hit product with best rate',
#  'nice product with low cost']

# %%
from nltk import tokenize
sentences=tokenize.sent_tokenize(', '.join(rev))

# %%
rev_df=pd.DataFrame(rev, columns=['sentences'])
rev_df
# Out:
#                                              sentences
# 0                               quality is good enough
# 1                                                 nice
# 2             fully satisfied with this brand new item
# 3    should not buy this ifb technology any product...
# 4                                                 good
# ..                                                 ...
# 624                                               nice
# 625                         thank you so much filpcard
# 626  nice product in good pricevalue for your money...
# 627             super duper hit product with best rate
# 628                         nice product with low cost
#
# [629 rows x 1 columns]

# %%
affinity_scores= afinn.set_index('word')['value'].to_dict()
affinity_scores
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
#  'admiring': 3,
#  'admit': -1,
#  'admits': -1,
#  'admitted': -1,
#  'admonish': -2,
#  'admonished': -2,
#  'adopt': 1,
#  'adopts': 1,
#  'adorable': 3,
#  'adore': 3,
#  'adored': 3,
#  'adores': 3,
#  'advanced': 1,
#  'advantage': 2,
#  'advantages': 2,
#  'adventure': 2,
#  'adventures': 2,
#  'adventurous': 2,
#  'affected': -1,
#  'affection': 3,
#  'affectionate': 3,
#  'afflicted': -1,
#  'affronted': -1,
#  'afraid': -2,
#  'aggravate': -2,
#  'aggravated': -2,
#  'aggravates': -2,
#  'aggravating': -2,
#  'aggression': -2,
#  'aggressions': -2,
#  'aggressive': -2,
#  'aghast': -2,
#  'agog': 2,
#  'agonise': -3,
#  'agonised': -3,
#  'agonises': -3,
#  'agonising': -3,
#  'agonize': -3,
#  'agonized': -3,
#  'agonizes': -3,
#  'agonizing': -3,
#  'agree': 1,
#  'agreeable': 2,
#  'agreed': 1,
#  'agreement': 1,
#  'agrees': 1,
#  'alarm': -2,
#  'alarmed': -2,
#  'alarmist': -2,
#  'alarmists': -2,
#  'alas': -1,
#  'alert': -1,
#  'alienation': -2,
#  'alive': 1,
#  'allergic': -2,
#  'allow': 1,
#  'alone': -2,
#  'amaze': 2,
#  'amazed': 2,
#  'amazes': 2,
#  'amazing': 4,
#  'ambitious': 2,
#  'ambivalent': -1,
#  'amuse': 3,
#  'amused': 3,
#  'amusement': 3,
#  'amusements': 3,
#  'anger': -3,
#  'angers': -3,
#  'angry': -3,
#  'anguish': -3,
#  'anguished': -3,
#  'animosity': -2,
#  'annoy': -2,
#  'annoyance': -2,
#  'annoyed': -2,
#  'annoying': -2,
#  'annoys': -2,
#  'antagonistic': -2,
#  'anti': -1,
#  'anticipation': 1,
#  'anxiety': -2,
#  'anxious': -2,
#  'apathetic': -3,
#  'apathy': -3,
#  'apeshit': -3,
#  'apocalyptic': -2,
#  'apologise': -1,
#  'apologised': -1,
#  'apologises': -1,
#  'apologising': -1,
#  'apologize': -1,
#  'apologized': -1,
#  'apologizes': -1,
#  'apologizing': -1,
#  'apology': -1,
#  'appalled': -2,
#  'appalling': -2,
#  'appease': 2,
#  'appeased': 2,
#  'appeases': 2,
#  'appeasing': 2,
#  'applaud': 2,
#  'applauded': 2,
#  'applauding': 2,
#  'applauds': 2,
#  'applause': 2,
#  'appreciate': 2,
#  'appreciated': 2,
#  'appreciates': 2,
#  'appreciating': 2,
#  'appreciation': 2,
#  'apprehensive': -2,
#  'approval': 2,
#  'approved': 2,
#  'approves': 2,
#  'ardent': 1,
#  'arrest': -2,
#  'arrested': -3,
#  'arrests': -2,
#  'arrogant': -2,
#  'ashame': -2,
#  'ashamed': -2,
#  'ass': -4,
#  'assassination': -3,
#  'assassinations': -3,
#  'asset': 2,
#  'assets': 2,
#  'assfucking': -4,
#  'asshole': -4,
#  'astonished': 2,
#  'astound': 3,
#  'astounded': 3,
#  'astounding': 3,
#  'astoundingly': 3,
#  'astounds': 3,
#  'attack': -1,
#  'attacked': -1,
#  'attacking': -1,
#  'attacks': -1,
#  'attract': 1,
#  'attracted': 1,
#  'attracting': 2,
#  'attraction': 2,
#  'attractions': 2,
#  'attracts': 1,
#  'audacious': 3,
#  'authority': 1,
#  'avert': -1,
#  'averted': -1,
#  'averts': -1,
#  'avid': 2,
#  'avoid': -1,
#  'avoided': -1,
#  'avoids': -1,
#  'await': -1,
#  'awaited': -1,
#  'awaits': -1,
#  'award': 3,
#  'awarded': 3,
#  'awards': 3,
#  'awesome': 4,
#  'awful': -3,
#  'awkward': -2,
#  'axe': -1,
#  'axed': -1,
#  'backed': 1,
#  'backing': 2,
#  'backs': 1,
#  'bad': -3,
#  'badass': -3,
#  'badly': -3,
#  'bailout': -2,
#  'bamboozle': -2,
#  'bamboozled': -2,
#  'bamboozles': -2,
#  'ban': -2,
#  'banish': -1,
#  'bankrupt': -3,
#  'bankster': -3,
#  'banned': -2,
#  'bargain': 2,
#  'barrier': -2,
#  'bastard': -5,
#  'bastards': -5,
#  'battle': -1,
#  'battles': -1,
#  'beaten': -2,
#  'beatific': 3,
#  'beating': -1,
#  'beauties': 3,
#  'beautiful': 3,
#  'beautifully': 3,
#  'beautify': 3,
#  'belittle': -2,
#  'belittled': -2,
#  'beloved': 3,
#  'benefit': 2,
#  'benefits': 2,
#  'benefitted': 2,
#  'benefitting': 2,
#  'bereave': -2,
#  'bereaved': -2,
#  'bereaves': -2,
#  'bereaving': -2,
#  'best': 3,
#  'betray': -3,
#  'betrayal': -3,
#  'betrayed': -3,
#  'betraying': -3,
#  'betrays': -3,
#  'better': 2,
#  'bias': -1,
#  'biased': -2,
#  'big': 1,
#  'bitch': -5,
#  'bitches': -5,
#  'bitter': -2,
#  'bitterly': -2,
#  'bizarre': -2,
#  'blah': -2,
#  'blame': -2,
#  'blamed': -2,
#  'blames': -2,
#  'blaming': -2,
#  'bless': 2,
#  'blesses': 2,
#  'blessing': 3,
#  'blind': -1,
#  'bliss': 3,
#  'blissful': 3,
#  'blithe': 2,
#  'block': -1,
#  'blockbuster': 3,
#  'blocked': -1,
#  'blocking': -1,
#  'blocks': -1,
#  'bloody': -3,
#  'blurry': -2,
#  'boastful': -2,
#  'bold': 2,
#  'boldly': 2,
#  'bomb': -1,
#  'boost': 1,
#  'boosted': 1,
#  'boosting': 1,
#  'boosts': 1,
#  'bore': -2,
#  'bored': -2,
#  'boring': -3,
#  'bother': -2,
#  'bothered': -2,
#  'bothers': -2,
#  'bothersome': -2,
#  'boycott': -2,
#  'boycotted': -2,
#  'boycotting': -2,
#  'boycotts': -2,
#  'brainwashing': -3,
#  'brave': 2,
#  'breakthrough': 3,
#  'breathtaking': 5,
#  'bribe': -3,
#  'bright': 1,
#  'brightest': 2,
#  'brightness': 1,
#  'brilliant': 4,
#  'brisk': 2,
#  'broke': -1,
#  'broken': -1,
#  'brooding': -2,
#  'bullied': -2,
#  'bullshit': -4,
#  'bully': -2,
#  'bullying': -2,
#  'bummer': -2,
#  'buoyant': 2,
#  'burden': -2,
#  'burdened': -2,
#  'burdening': -2,
#  'burdens': -2,
#  'calm': 2,
#  'calmed': 2,
#  'calming': 2,
#  'calms': 2,
#  "can't stand": -3,
#  'cancel': -1,
#  'cancelled': -1,
#  'cancelling': -1,
#  'cancels': -1,
#  'cancer': -1,
#  'capable': 1,
#  'captivated': 3,
#  'care': 2,
#  'carefree': 1,
#  'careful': 2,
#  'carefully': 2,
#  'careless': -2,
#  'cares': 2,
#  'cashing in': -2,
#  'casualty': -2,
#  'catastrophe': -3,
#  'catastrophic': -4,
#  'cautious': -1,
#  'celebrate': 3,
#  'celebrated': 3,
#  'celebrates': 3,
#  'celebrating': 3,
#  'censor': -2,
#  'censored': -2,
#  'censors': -2,
#  'certain': 1,
#  'chagrin': -2,
#  'chagrined': -2,
#  'challenge': -1,
#  'chance': 2,
#  'chances': 2,
#  'chaos': -2,
#  'chaotic': -2,
#  'charged': -3,
#  'charges': -2,
#  'charm': 3,
#  'charming': 3,
#  'charmless': -3,
#  'chastise': -3,
#  'chastised': -3,
#  'chastises': -3,
#  'chastising': -3,
#  'cheat': -3,
#  'cheated': -3,
#  'cheater': -3,
#  'cheaters': -3,
#  'cheats': -3,
#  'cheer': 2,
#  'cheered': 2,
#  'cheerful': 2,
#  'cheering': 2,
#  'cheerless': -2,
#  'cheers': 2,
#  'cheery': 3,
#  'cherish': 2,
#  'cherished': 2,
#  'cherishes': 2,
#  'cherishing': 2,
#  'chic': 2,
#  'childish': -2,
#  'chilling': -1,
#  'choke': -2,
#  'choked': -2,
#  'chokes': -2,
#  'choking': -2,
#  'clarifies': 2,
#  'clarity': 2,
#  'clash': -2,
#  'classy': 3,
#  'clean': 2,
#  'cleaner': 2,
#  'clear': 1,
#  'cleared': 1,
#  'clearly': 1,
#  'clears': 1,
#  'clever': 2,
#  'clouded': -1,
#  'clueless': -2,
#  'cock': -5,
#  'cocksucker': -5,
#  'cocksuckers': -5,
#  'cocky': -2,
#  'coerced': -2,
#  'collapse': -2,
#  'collapsed': -2,
#  'collapses': -2,
#  'collapsing': -2,
#  'collide': -1,
#  'collides': -1,
#  'colliding': -1,
#  'collision': -2,
#  'collisions': -2,
#  'colluding': -3,
#  'combat': -1,
#  'combats': -1,
#  'comedy': 1,
#  'comfort': 2,
#  'comfortable': 2,
#  'comforting': 2,
#  'comforts': 2,
#  'commend': 2,
#  'commended': 2,
#  'commit': 1,
#  'commitment': 2,
#  'commits': 1,
#  'committed': 1,
#  'committing': 1,
#  'compassionate': 2,
#  'compelled': 1,
#  'competent': 2,
#  'competitive': 2,
#  'complacent': -2,
#  'complain': -2,
#  'complained': -2,
#  'complains': -2,
#  'comprehensive': 2,
#  'conciliate': 2,
#  'conciliated': 2,
#  'conciliates': 2,
#  'conciliating': 2,
#  'condemn': -2,
#  'condemnation': -2,
#  'condemned': -2,
#  'condemns': -2,
#  'confidence': 2,
#  'confident': 2,
#  'conflict': -2,
#  'conflicting': -2,
#  'conflictive': -2,
#  'conflicts': -2,
#  'confuse': -2,
#  'confused': -2,
#  'confusing': -2,
#  'congrats': 2,
#  'congratulate': 2,
#  'congratulation': 2,
#  'congratulations': 2,
#  'consent': 2,
#  'consents': 2,
#  'consolable': 2,
#  'conspiracy': -3,
#  'constrained': -2,
#  'contagion': -2,
#  'contagions': -2,
#  'contagious': -1,
#  'contempt': -2,
#  'contemptuous': -2,
#  'contemptuously': -2,
#  'contend': -1,
#  'contender': -1,
#  'contending': -1,
#  'contentious': -2,
#  'contestable': -2,
#  'controversial': -2,
#  'controversially': -2,
#  'convince': 1,
#  'convinced': 1,
#  'convinces': 1,
#  'convivial': 2,
#  'cool': 1,
#  'cool stuff': 3,
#  'cornered': -2,
#  'corpse': -1,
#  'costly': -2,
#  'courage': 2,
#  'courageous': 2,
#  'courteous': 2,
#  'courtesy': 2,
#  'cover-up': -3,
#  'coward': -2,
#  'cowardly': -2,
#  'coziness': 2,
#  'cramp': -1,
#  'crap': -3,
#  'crash': -2,
#  'crazier': -2,
#  'craziest': -2,
#  'crazy': -2,
#  'creative': 2,
#  'crestfallen': -2,
#  'cried': -2,
#  'cries': -2,
#  'crime': -3,
#  'criminal': -3,
#  'criminals': -3,
#  'crisis': -3,
#  'critic': -2,
#  'criticism': -2,
#  'criticize': -2,
#  'criticized': -2,
#  'criticizes': -2,
#  'criticizing': -2,
#  'critics': -2,
#  'cruel': -3,
#  'cruelty': -3,
#  'crush': -1,
#  'crushed': -2,
#  'crushes': -1,
#  'crushing': -1,
#  'cry': -1,
#  'crying': -2,
#  'cunt': -5,
#  'curious': 1,
#  'curse': -1,
#  'cut': -1,
#  'cute': 2,
#  'cuts': -1,
#  'cutting': -1,
#  'cynic': -2,
#  'cynical': -2,
#  'cynicism': -2,
#  'damage': -3,
#  'damages': -3,
#  'damn': -4,
#  'damned': -4,
#  'damnit': -4,
#  'danger': -2,
#  'daredevil': 2,
#  'daring': 2,
#  'darkest': -2,
#  'darkness': -1,
#  'dauntless': 2,
#  'dead': -3,
#  'deadlock': -2,
#  'deafening': -1,
#  'dear': 2,
#  'dearly': 3,
#  'death': -2,
#  'debonair': 2,
#  'debt': -2,
#  'deceit': -3,
#  'deceitful': -3,
#  'deceive': -3,
#  'deceived': -3,
#  'deceives': -3,
#  'deceiving': -3,
#  'deception': -3,
#  'decisive': 1,
#  'dedicated': 2,
#  'defeated': -2,
#  'defect': -3,
#  'defects': -3,
#  'defender': 2,
#  'defenders': 2,
#  'defenseless': -2,
#  'defer': -1,
#  'deferring': -1,
#  'defiant': -1,
#  'deficit': -2,
#  'degrade': -2,
#  'degraded': -2,
#  'degrades': -2,
#  'dehumanize': -2,
#  'dehumanized': -2,
#  'dehumanizes': -2,
#  'dehumanizing': -2,
#  'deject': -2,
#  'dejected': -2,
#  'dejecting': -2,
#  'dejects': -2,
#  'delay': -1,
#  'delayed': -1,
#  'delight': 3,
#  'delighted': 3,
#  'delighting': 3,
#  'delights': 3,
#  'demand': -1,
#  'demanded': -1,
#  'demanding': -1,
#  'demands': -1,
#  'demonstration': -1,
#  'demoralized': -2,
#  'denied': -2,
#  'denier': -2,
#  'deniers': -2,
#  'denies': -2,
#  'denounce': -2,
#  'denounces': -2,
#  'deny': -2,
#  'denying': -2,
#  'depressed': -2,
#  'depressing': -2,
#  'derail': -2,
#  'derailed': -2,
#  'derails': -2,
#  'deride': -2,
#  'derided': -2,
#  'derides': -2,
#  'deriding': -2,
#  'derision': -2,
#  'desirable': 2,
#  'desire': 1,
#  'desired': 2,
#  'desirous': 2,
#  'despair': -3,
#  'despairing': -3,
#  'despairs': -3,
#  'desperate': -3,
#  'desperately': -3,
#  'despondent': -3,
#  'destroy': -3,
#  'destroyed': -3,
#  'destroying': -3,
#  'destroys': -3,
#  'destruction': -3,
#  'destructive': -3,
#  'detached': -1,
#  'detain': -2,
#  'detained': -2,
#  'detention': -2,
#  'determined': 2,
#  'devastate': -2,
#  'devastated': -2,
#  'devastating': -2,
#  'devoted': 3,
#  'diamond': 1,
#  'dick': -4,
#  'dickhead': -4,
#  'die': -3,
#  'died': -3,
#  'difficult': -1,
#  'diffident': -2,
#  'dilemma': -1,
#  'dipshit': -3,
#  'dire': -3,
#  'direful': -3,
#  'dirt': -2,
#  'dirtier': -2,
#  'dirtiest': -2,
#  'dirty': -2,
#  'disabling': -1,
#  'disadvantage': -2,
#  'disadvantaged': -2,
#  'disappear': -1,
#  'disappeared': -1,
#  'disappears': -1,
#  'disappoint': -2,
#  'disappointed': -2,
#  'disappointing': -2,
#  'disappointment': -2,
#  'disappointments': -2,
#  'disappoints': -2,
#  'disaster': -2,
#  'disasters': -2,
#  'disastrous': -3,
#  'disbelieve': -2,
#  'discard': -1,
#  'discarded': -1,
#  'discarding': -1,
#  'discards': -1,
#  'disconsolate': -2,
#  'disconsolation': -2,
#  'discontented': -2,
#  'discord': -2,
#  'discounted': -1,
#  'discouraged': -2,
#  'discredited': -2,
#  'disdain': -2,
#  'disgrace': -2,
#  'disgraced': -2,
#  'disguise': -1,
#  'disguised': -1,
#  'disguises': -1,
#  'disguising': -1,
#  'disgust': -3,
#  'disgusted': -3,
#  'disgusting': -3,
#  'disheartened': -2,
#  'dishonest': -2,
#  'disillusioned': -2,
#  'disinclined': -2,
#  'disjointed': -2,
#  'dislike': -2,
#  'dismal': -2,
#  'dismayed': -2,
#  'disorder': -2,
#  'disorganized': -2,
#  'disoriented': -2,
#  'disparage': -2,
#  'disparaged': -2,
#  'disparages': -2,
#  'disparaging': -2,
#  'displeased': -2,
#  'dispute': -2,
#  'disputed': -2,
#  'disputes': -2,
#  'disputing': -2,
#  'disqualified': -2,
#  'disquiet': -2,
#  'disregard': -2,
#  'disregarded': -2,
#  'disregarding': -2,
#  'disregards': -2,
#  'disrespect': -2,
#  'disrespected': -2,
#  'disruption': -2,
#  'disruptions': -2,
#  'disruptive': -2,
#  'dissatisfied': -2,
#  'distort': -2,
#  'distorted': -2,
#  'distorting': -2,
#  'distorts': -2,
#  'distract': -2,
#  'distracted': -2,
#  'distraction': -2,
#  'distracts': -2,
#  'distress': -2,
#  'distressed': -2,
#  'distresses': -2,
#  'distressing': -2,
#  'distrust': -3,
#  'distrustful': -3,
#  'disturb': -2,
#  'disturbed': -2,
#  'disturbing': -2,
#  'disturbs': -2,
#  'dithering': -2,
#  'dizzy': -1,
#  'dodging': -2,
#  'dodgy': -2,
#  'does not work': -3,
#  'dolorous': -2,
#  'dont like': -2,
#  'doom': -2,
#  'doomed': -2,
#  'doubt': -1,
#  'doubted': -1,
#  'doubtful': -1,
#  'doubting': -1,
#  'doubts': -1,
#  'douche': -3,
#  'douchebag': -3,
#  'downcast': -2,
#  'downhearted': -2,
#  'downside': -2,
#  'drag': -1,
#  'dragged': -1,
#  'drags': -1,
#  'drained': -2,
#  'dread': -2,
#  'dreaded': -2,
#  'dreadful': -3,
#  'dreading': -2,
#  'dream': 1,
#  'dreams': 1,
#  'dreary': -2,
#  'droopy': -2,
#  'drop': -1,
#  'drown': -2,
#  'drowned': -2,
#  'drowns': -2,
#  'drunk': -2,
#  'dubious': -2,
#  'dud': -2,
#  'dull': -2,
#  'dumb': -3,
#  'dumbass': -3,
#  'dump': -1,
#  'dumped': -2,
#  'dumps': -1,
#  'dupe': -2,
#  'duped': -2,
#  'dysfunction': -2,
#  'eager': 2,
#  'earnest': 2,
#  'ease': 2,
#  'easy': 1,
#  'ecstatic': 4,
#  'eerie': -2,
#  'eery': -2,
#  'effective': 2,
#  'effectively': 2,
#  'elated': 3,
#  'elation': 3,
#  'elegant': 2,
#  'elegantly': 2,
#  'embarrass': -2,
#  'embarrassed': -2,
#  'embarrasses': -2,
#  'embarrassing': -2,
#  'embarrassment': -2,
#  'embittered': -2,
#  'embrace': 1,
#  'emergency': -2,
#  'empathetic': 2,
#  'emptiness': -1,
#  'empty': -1,
#  'enchanted': 2,
#  'encourage': 2,
#  'encouraged': 2,
#  'encouragement': 2,
#  'encourages': 2,
#  'endorse': 2,
#  'endorsed': 2,
#  'endorsement': 2,
#  'endorses': 2,
#  'enemies': -2,
#  'enemy': -2,
#  'energetic': 2,
#  'engage': 1,
#  'engages': 1,
#  'engrossed': 1,
#  'enjoy': 2,
#  'enjoying': 2,
#  'enjoys': 2,
#  'enlighten': 2,
#  'enlightened': 2,
#  'enlightening': 2,
#  'enlightens': 2,
#  'ennui': -2,
#  'enrage': -2,
#  'enraged': -2,
#  'enrages': -2,
#  'enraging': -2,
#  'enrapture': 3,
#  'enslave': -2,
#  'enslaved': -2,
#  'enslaves': -2,
#  'ensure': 1,
#  'ensuring': 1,
#  'enterprising': 1,
#  'entertaining': 2,
#  'enthral': 3,
#  'enthusiastic': 3,
#  'entitled': 1,
#  'entrusted': 2,
#  'envies': -1,
#  'envious': -2,
#  'envy': -1,
#  'envying': -1,
#  'erroneous': -2,
#  'error': -2,
#  'errors': -2,
#  'escape': -1,
#  'escapes': -1,
#  'escaping': -1,
#  'esteemed': 2,
#  'ethical': 2,
#  'euphoria': 3,
#  'euphoric': 4,
#  'eviction': -1,
#  'evil': -3,
#  'exaggerate': -2,
#  'exaggerated': -2,
#  'exaggerates': -2,
#  'exaggerating': -2,
#  'exasperated': 2,
#  'excellence': 3,
#  'excellent': 3,
#  'excite': 3,
#  'excited': 3,
#  'excitement': 3,
#  'exciting': 3,
#  'exclude': -1,
#  'excluded': -2,
#  'exclusion': -1,
#  'exclusive': 2,
#  'excuse': -1,
#  'exempt': -1,
#  'exhausted': -2,
#  'exhilarated': 3,
#  'exhilarates': 3,
#  'exhilarating': 3,
#  'exonerate': 2,
#  'exonerated': 2,
#  'exonerates': 2,
#  'exonerating': 2,
#  'expand': 1,
#  'expands': 1,
#  'expel': -2,
#  'expelled': -2,
#  'expelling': -2,
#  'expels': -2,
#  'exploit': -2,
#  'exploited': -2,
#  'exploiting': -2,
#  'exploits': -2,
#  'exploration': 1,
#  'explorations': 1,
#  'expose': -1,
#  'exposed': -1,
#  'exposes': -1,
#  'exposing': -1,
#  'extend': 1,
#  'extends': 1,
#  'exuberant': 4,
#  'exultant': 3,
#  'exultantly': 3,
#  'fabulous': 4,
#  'fad': -2,
#  'fag': -3,
#  'faggot': -3,
#  'faggots': -3,
#  'fail': -2,
#  'failed': -2,
#  'failing': -2,
#  'fails': -2,
#  'failure': -2,
#  'failures': -2,
#  'fainthearted': -2,
#  'fair': 2,
#  'faith': 1,
#  'faithful': 3,
#  'fake': -3,
#  'fakes': -3,
#  'faking': -3,
#  'fallen': -2,
#  'falling': -1,
#  'falsified': -3,
#  'falsify': -3,
#  'fame': 1,
#  'fan': 3,
#  'fantastic': 4,
#  'farce': -1,
#  'fascinate': 3,
#  'fascinated': 3,
#  'fascinates': 3,
#  'fascinating': 3,
#  'fascist': -2,
#  'fascists': -2,
#  'fatalities': -3,
#  'fatality': -3,
#  'fatigue': -2,
#  'fatigued': -2,
#  'fatigues': -2,
#  'fatiguing': -2,
#  'favor': 2,
#  'favored': 2,
#  'favorite': 2,
#  'favorited': 2,
#  'favorites': 2,
#  'favors': 2,
#  'fear': -2,
#  'fearful': -2,
#  'fearing': -2,
#  'fearless': 2,
#  'fearsome': -2,
#  'fed up': -3,
#  'feeble': -2,
#  'feeling': 1,
#  'felonies': -3,
#  'felony': -3,
#  'fervent': 2,
#  'fervid': 2,
#  'festive': 2,
#  'fiasco': -3,
#  'fidgety': -2,
#  'fight': -1,
#  'fine': 2,
#  'fire': -2,
#  'fired': -2,
#  'firing': -2,
#  'fit': 1,
#  'fitness': 1,
#  'flagship': 2,
#  'flees': -1,
#  'flop': -2,
#  'flops': -2,
#  'flu': -2,
#  ...}

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
nlp= spacy.load('en_core_web_sm')
sentiment_lexicon=affinity_scores

def calculate_sentiment (text: str=None):
    sent_score=0
    if text:
        sentence=nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_,0)
    return sent_score

# %%
# test that it works
calculate_sentiment(text='good')
# Out:
# 3

# %%
rev_df['sentiment_value']=rev_df['sentences'].apply(calculate_sentiment)

# %%
 #how many words are in the sentence?
rev_df['word_count']=rev_df['sentences'].str.split().apply(len)
rev_df['word_count']
# Out:
# 0       4
# 1       1
# 2       7
# 3      25
# 4       1
#        ..
# 624     1
# 625     5
# 626    11
# 627     7
# 628     5
# Name: word_count, Length: 629, dtype: int64

# %%
rev_df.sort_values(by='sentiment_value',ascending=False)
# Out:
#                                              sentences  sentiment_value  \
# 191  very good product and very low noice we loved ...               14
# 485  awesome product from flip kart and ifb good de...               14
# 496  its an awesome washing machine tough durablego...               13
# 65   outstanding performance and installation guys ...               11
# 325  great discounts superb serviceifb washing mach...               11
# ..                                                 ...              ...
# 610  product is value for money but a little noisy ...               -7
# 541  product was too bad and worst service from fli...               -8
# 312  machine performance is too bad every   technic...               -8
# 32   worst experience with ifb washing machine   fr...              -10
# 39   very worst no body installation very very wors...              -12
#
#      word_count
# 191          30
# 485          20
# 496          40
# 65           10
# 325           9
# ..          ...
# 610          20
# 541          26
# 312          13
# 32           50
# 39           17
#
# [629 rows x 3 columns]

# %%
# Sentiment score of the whole review
rev_df['sentiment_value'].describe()
# Out:
# count    629.000000
# mean       2.616852
# std        3.047047
# min      -12.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max       14.000000
# Name: sentiment_value, dtype: float64

# %%
rev_df[rev_df['sentiment_value']<0]
# Out:
#                                              sentences  sentiment_value  \
# 3    should not buy this ifb technology any product...               -2
# 9    after using   is not working so many times err...               -5
# 26   the worst service ever first of all if u r tak...               -3
# 32   worst experience with ifb washing machine   fr...              -10
# 33   washing time has neither mentioned on flipkart...               -1
# ..                                                 ...              ...
# 606  installstion person worst explained and not  f...               -3
# 609  dont buy thistaking lot of timeno display  we ...               -3
# 610  product is value for money but a little noisy ...               -7
# 619                                       damaged item               -3
# 621  flipkart people reducing the exchange value fo...               -3
#
#      word_count
# 3            25
# 9            16
# 26           96
# 32           50
# 33           32
# ..          ...
# 606           8
# 609          43
# 610          20
# 619           2
# 621          31
#
# [63 rows x 3 columns]

# %%
rev_df[rev_df['sentiment_value']>0]
# Out:
#                                              sentences  sentiment_value  \
# 0                               quality is good enough                3
# 1                                                 nice                3
# 2             fully satisfied with this brand new item                2
# 4                                                 good                3
# 7                              awesome thanks flipkart                6
# ..                                                 ...              ...
# 624                                               nice                3
# 625                         thank you so much filpcard                2
# 626  nice product in good pricevalue for your money...                6
# 627             super duper hit product with best rate                6
# 628                         nice product with low cost                3
#
#      word_count
# 0             4
# 1             1
# 2             7
# 4             1
# 7             3
# ..          ...
# 624           1
# 625           5
# 626          11
# 627           7
# 628           5
#
# [490 rows x 3 columns]

# %%
import seaborn as sns
sns.distplot(rev_df['sentiment_value'])
#From this distplot we can see that there is  positive overall review and most of the reviews are positive as the bar is high in between 0 to 5 where 0 indicates neutral
# Out:
# C:\Users\MOHD SHOEB\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sentiment_value', ylabel='Density'>

# %%
rev_df['sentiment_value'].sum(axis=0)
# Out:
# 1646

# %%
rev_df['index']=range(0,len(rev_df))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,17))
sns.lineplot(y='sentiment_value', x='index',data=rev_df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='sentiment_value'>
